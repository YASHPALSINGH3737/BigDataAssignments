# %% [markdown]
# <a href="https://colab.research.google.com/github/YASHPALSINGH3737/BigDataAssignments/blob/master/0909_vectors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.quiver(0,0,3,4)  #initial 0,0 are initial co-oridnates, later 3,4 are final co-ordinates of the vector
plt.show()

# %%
plt.quiver(0,0,3,4, scale_units='xy', angles='xy', scale=1)
plt.show()

# %%
plt.quiver(0,0,3,4, scale_units='xy', angles='xy', scale=1)
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
plt.quiver(0,0,3,4, scale_units='xy', angles='xy', scale=1, color='r')
plt.quiver(0,0,-3,4, scale_units='xy', angles='xy', scale=1, color='g')
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
def plot_vectors(vecs):
  i = 0
  for vec in vecs:
    colors =['r','b','g','y']
    plt.quiver(vec[0], vec[1], vec[2], vec[3], scale_units='xy', angles='xy', scale=1, color=colors[i%len(colors)])
    i += 1
  plt.xlim(-10,10)
  plt.ylim(-10,10)
  plt.show()

# %%
plot_vectors([(0,0,3,4)])

# %%
plot_vectors([(0,0,3,4), (0,0,-3,4), (0,0,-3,-2), (0,0,-3,-1)])
